# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
start = '2015-01-01'

# %%
overall = pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")[0]

# %%
overalls
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# 2                 Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                       Pharmaceuticals  North Chicago, Illinois  2012-12-31
# 4        IT Consulting & Other Services          Dublin, Ireland  2011-07-06
# ..                                  ...                      ...         ...
# 498                         Restaurants     Louisville, Kentucky  1997-10-06
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois  2019-12-23
# 500               Health Care Equipment          Warsaw, Indiana  2001-08-07
# 501                      Regional Banks     Salt Lake City, Utah  2001-06-22
# 502                     Pharmaceuticals   Parsippany, New Jersey  2013-06-21
#
#          CIK      Founded
# 0      66740         1902
# 1      91142         1916
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4    1467373         1989
# ..       ...          ...
# 498  1041061         1997
# 499   877212         1969
# 500  1136869         1927
# 501   109380         1873
# 502  1555280         1952
#
# [503 rows x 8 columns]

# %%
stocks = overall.Symbol

# %%
stocks
# Out:
# 0       MMM
# 1       AOS
# 2       ABT
# 3      ABBV
# 4       ACN
#        ...
# 498     YUM
# 499    ZBRA
# 500     ZBH
# 501    ZION
# 502     ZTS
# Name: Symbol, Length: 503, dtype: object

# %%
stocks = stocks.to_list()

# %%
stocks
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AES',
#  'AFL',
#  'A',
#  'ABNB',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'WRB',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BX',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'BG',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'COR',
#  'CNC',
#  'CNP',
#  'CDAY',
#  'CF',
#  'CRL',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CMA',
#  'CAG',
#  'COP',
#  'ED',
#  'STZ',
#  'CEG',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CTVA',
#  'CSGP',
#  'COST',
#  'CTRA',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHI',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DE',
#  'DAL',
#  'XRAY',
#  'DVN',
#  'DXCM',
#  'FANG',
#  'DLR',
#  'DFS',
#  'DIS',
#  'DG',
#  'DLTR',
#  'D',
#  'DPZ',
#  'DOV',
#  'DOW',
#  'DTE',
#  'DUK',
#  'DD',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'ELV',
#  'LLY',
#  'EMR',
#  'ENPH',
#  'ETR',
#  'EOG',
#  'EPAM',
#  'EQT',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ESS',
#  'EL',
#  'ETSY',
#  'EG',
#  'EVRG',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FDS',
#  'FICO',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FITB',
#  'FSLR',
#  'FE',
#  'FIS',
#  'FI',
#  'FLT',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'GRMN',
#  'IT',
#  'GEHC',
#  'GEN',
#  'GNRC',
#  'GD',
#  'GE',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GL',
#  'GPN',
#  'GS',
#  'HAL',
#  'HIG',
#  'HAS',
#  'HCA',
#  'PEAK',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUBB',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IBM',
#  'IEX',
#  'IDXX',
#  'ITW',
#  'ILMN',
#  'INCY',
#  'IR',
#  'PODD',
#  'INTC',
#  'ICE',
#  'IFF',
#  'IP',
#  'IPG',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'INVH',
#  'IQV',
#  'IRM',
#  'JBHT',
#  'JKHY',
#  'J',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'K',
#  'KVUE',
#  'KDP',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KLAC',
#  'KHC',
#  'KR',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LDOS',
#  'LEN',
#  'LIN',
#  'LYV',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LULU',
#  'LYB',
#  'MTB',
#  'MRO',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MTCH',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'META',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MRNA',
#  'MHK',
#  'MOH',
#  'TAP',
#  'MDLZ',
#  'MPWR',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'NDAQ',
#  'NTAP',
#  'NFLX',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NKE',
#  'NI',
#  'NDSN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NXPI',
#  'ORLY',
#  'OXY',
#  'ODFL',
#  'OMC',
#  'ON',
#  'OKE',
#  'ORCL',
#  'OTIS',
#  'PCAR',
#  'PKG',
#  'PANW',
#  'PARA',
#  'PH',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PNR',
#  'PEP',
#  'PFE',
#  'PCG',
#  'PM',
#  'PSX',
#  'PNW',
#  'PXD',
#  'PNC',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PTC',
#  'PSA',
#  'PHM',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RVTY',
#  'RHI',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SEE',
#  'SRE',
#  'NOW',
#  'SHW',
#  'SPG',
#  'SWKS',
#  'SJM',
#  'SNA',
#  'SEDG',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'STLD',
#  'STE',
#  'SYK',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TRGP',
#  'TGT',
#  'TEL',
#  'TDY',
#  'TFX',
#  'TER',
#  'TSLA',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TRMB',
#  'TFC',
#  'TYL',
#  'TSN',
#  'USB',
#  'UDR',
#  'ULTA',
#  'UNP',
#  'UAL',
#  'UPS',
#  'URI',
#  'UNH',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VLTO',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VFC',
#  'VTRS',
#  'VICI',
#  'V',
#  'VMC',
#  'WAB',
#  'WBA',
#  'WMT',
#  'WBD',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WST',
#  'WDC',
#  'WRK',
#  'WY',
#  'WHR',
#  'WMB',
#  'WTW',
#  'GWW',
#  'WYNN',
#  'XEL',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZION',
#  'ZTS']

# %%
overall = overall[overall['Date added'] >= start]

# %%
overall
# Out:
#     Symbol                         Security             GICS Sector  \
# 1      AOS                      A. O. Smith             Industrials
# 11    ABNB                           Airbnb  Consumer Discretionary
# 14     ALK                 Alaska Air Group             Industrials
# 15     ALB            Albemarle Corporation               Materials
# 16     ARE  Alexandria Real Estate Equities             Real Estate
# ..     ...                              ...                     ...
# 478    WAB                           Wabtec             Industrials
# 481    WBD           Warner Bros. Discovery  Communication Services
# 487    WST     West Pharmaceutical Services             Health Care
# 493    WTW             Willis Towers Watson              Financials
# 499   ZBRA               Zebra Technologies  Information Technology
#
#                                      GICS Sub-Industry  \
# 1                                    Building Products
# 11                      Hotels, Resorts & Cruise Lines
# 14                                  Passenger Airlines
# 15                                 Specialty Chemicals
# 16                                        Office REITs
# ..                                                 ...
# 478  Construction Machinery & Heavy Transportation ...
# 481                                       Broadcasting
# 487                               Health Care Supplies
# 493                                  Insurance Brokers
# 499                 Electronic Equipment & Instruments
#
#          Headquarters Location  Date added      CIK                   Founded
# 1         Milwaukee, Wisconsin  2017-07-26    91142                      1916
# 11   San Francisco, California  2023-09-18  1559720                      2008
# 14          SeaTac, Washington  2016-05-13   766421                      1985
# 15   Charlotte, North Carolina  2016-07-01   915913                      1994
# 16        Pasadena, California  2017-03-20  1035443                      1994
# ..                         ...         ...      ...                       ...
# 478   Pittsburgh, Pennsylvania  2019-02-27   943452               1999 (1869)
# 481    New York City, New York  2022-04-11  1437107  2022 (Warner Bros. 1923)
# 487        Exton, Pennsylvania  2020-05-22   105770                      1923
# 493     London, United Kingdom  2016-01-05  1140536                      2016
# 499     Lincolnshire, Illinois  2019-12-23   877212                      1969
#
# [159 rows x 8 columns]

# %%
removed = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[1][['Date','Removed']]

# %%
removed
# Out:
#                    Date Removed
#                    Date  Ticker                      Security
# 0      October 18, 2023     OGN                 Organon & Co.
# 1      October 18, 2023    ATVI           Activision Blizzard
# 2       October 3, 2023     DXC                DXC Technology
# 3       October 2, 2023     NaN                           NaN
# 4    September 18, 2023     LNC  Lincoln National Corporation
# ..                  ...     ...                           ...
# 329        June 9, 1999     HPH      Harnischfeger Industries
# 330   December 11, 1998     LDW                         Amoco
# 331   December 11, 1998     GRN                    General Re
# 332   December 11, 1998     SUN                    SunAmerica
# 333       June 17, 1997     USL                        USLife
#
# [334 rows x 3 columns]

# %%
removed = removed.set_index(removed.Date.Date)

# %%
removed
# Out:
#                                   Date Removed
#                                   Date  Ticker                      Security
# Date
# October 18, 2023      October 18, 2023     OGN                 Organon & Co.
# October 18, 2023      October 18, 2023    ATVI           Activision Blizzard
# October 3, 2023        October 3, 2023     DXC                DXC Technology
# October 2, 2023        October 2, 2023     NaN                           NaN
# September 18, 2023  September 18, 2023     LNC  Lincoln National Corporation
# ...                                ...     ...                           ...
# June 9, 1999              June 9, 1999     HPH      Harnischfeger Industries
# December 11, 1998    December 11, 1998     LDW                         Amoco
# December 11, 1998    December 11, 1998     GRN                    General Re
# December 11, 1998    December 11, 1998     SUN                    SunAmerica
# June 17, 1997            June 17, 1997     USL                        USLife
#
# [334 rows x 3 columns]

# %%
removed.index = pd.to_datetime(removed.index)

# %%
removed
# Out:
#                           Date Removed
#                           Date  Ticker                      Security
# Date
# 2023-10-18    October 18, 2023     OGN                 Organon & Co.
# 2023-10-18    October 18, 2023    ATVI           Activision Blizzard
# 2023-10-03     October 3, 2023     DXC                DXC Technology
# 2023-10-02     October 2, 2023     NaN                           NaN
# 2023-09-18  September 18, 2023     LNC  Lincoln National Corporation
# ...                        ...     ...                           ...
# 1999-06-09        June 9, 1999     HPH      Harnischfeger Industries
# 1998-12-11   December 11, 1998     LDW                         Amoco
# 1998-12-11   December 11, 1998     GRN                    General Re
# 1998-12-11   December 11, 1998     SUN                    SunAmerica
# 1997-06-17       June 17, 1997     USL                        USLife
#
# [334 rows x 3 columns]

# %%
removed = removed[removed.index >= start]

# %%
removed
# Out:
#                           Date Removed
#                           Date  Ticker                      Security
# Date
# 2023-10-18    October 18, 2023     OGN                 Organon & Co.
# 2023-10-18    October 18, 2023    ATVI           Activision Blizzard
# 2023-10-03     October 3, 2023     DXC                DXC Technology
# 2023-10-02     October 2, 2023     NaN                           NaN
# 2023-09-18  September 18, 2023     LNC  Lincoln National Corporation
# ...                        ...     ...                           ...
# 2015-03-23      March 23, 2015     AVP                 Avon Products
# 2015-03-18      March 18, 2015     CFN                    Carefusion
# 2015-03-12      March 12, 2015    PETM                      PetSmart
# 2015-01-27    January 27, 2015     SWY                       Safeway
# 2015-01-27    January 27, 2015     COV                      Covidien
#
# [204 rows x 3 columns]

# %%
removed = removed.Removed.dropna()

# %%
removed
# Out:
#            Ticker                      Security
# Date
# 2023-10-18    OGN                 Organon & Co.
# 2023-10-18   ATVI           Activision Blizzard
# 2023-10-03    DXC                DXC Technology
# 2023-09-18    LNC  Lincoln National Corporation
# 2023-09-18    NWL                 Newell Brands
# ...           ...                           ...
# 2015-03-23    AVP                 Avon Products
# 2015-03-18    CFN                    Carefusion
# 2015-03-12   PETM                      PetSmart
# 2015-01-27    SWY                       Safeway
# 2015-01-27    COV                      Covidien
#
# [192 rows x 2 columns]

# %%
removed = removed.iloc[::-1]

# %%
removed
# Out:
#            Ticker                      Security
# Date
# 2015-01-27    COV                      Covidien
# 2015-01-27    SWY                       Safeway
# 2015-03-12   PETM                      PetSmart
# 2015-03-18    CFN                    Carefusion
# 2015-03-23    AVP                 Avon Products
# ...           ...                           ...
# 2023-09-18    NWL                 Newell Brands
# 2023-09-18    LNC  Lincoln National Corporation
# 2023-10-03    DXC                DXC Technology
# 2023-10-18   ATVI           Activision Blizzard
# 2023-10-18    OGN                 Organon & Co.
#
# [192 rows x 2 columns]

# %%
stocks.extend(removed.Ticker.to_list())

# %%
stocks
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AES',
#  'AFL',
#  'A',
#  'ABNB',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'WRB',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BX',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'BG',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'COR',
#  'CNC',
#  'CNP',
#  'CDAY',
#  'CF',
#  'CRL',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CMA',
#  'CAG',
#  'COP',
#  'ED',
#  'STZ',
#  'CEG',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CTVA',
#  'CSGP',
#  'COST',
#  'CTRA',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHI',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DE',
#  'DAL',
#  'XRAY',
#  'DVN',
#  'DXCM',
#  'FANG',
#  'DLR',
#  'DFS',
#  'DIS',
#  'DG',
#  'DLTR',
#  'D',
#  'DPZ',
#  'DOV',
#  'DOW',
#  'DTE',
#  'DUK',
#  'DD',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'ELV',
#  'LLY',
#  'EMR',
#  'ENPH',
#  'ETR',
#  'EOG',
#  'EPAM',
#  'EQT',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ESS',
#  'EL',
#  'ETSY',
#  'EG',
#  'EVRG',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FDS',
#  'FICO',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FITB',
#  'FSLR',
#  'FE',
#  'FIS',
#  'FI',
#  'FLT',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'GRMN',
#  'IT',
#  'GEHC',
#  'GEN',
#  'GNRC',
#  'GD',
#  'GE',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GL',
#  'GPN',
#  'GS',
#  'HAL',
#  'HIG',
#  'HAS',
#  'HCA',
#  'PEAK',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUBB',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IBM',
#  'IEX',
#  'IDXX',
#  'ITW',
#  'ILMN',
#  'INCY',
#  'IR',
#  'PODD',
#  'INTC',
#  'ICE',
#  'IFF',
#  'IP',
#  'IPG',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'INVH',
#  'IQV',
#  'IRM',
#  'JBHT',
#  'JKHY',
#  'J',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'K',
#  'KVUE',
#  'KDP',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KLAC',
#  'KHC',
#  'KR',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LDOS',
#  'LEN',
#  'LIN',
#  'LYV',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LULU',
#  'LYB',
#  'MTB',
#  'MRO',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MTCH',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'META',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MRNA',
#  'MHK',
#  'MOH',
#  'TAP',
#  'MDLZ',
#  'MPWR',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'NDAQ',
#  'NTAP',
#  'NFLX',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NKE',
#  'NI',
#  'NDSN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NXPI',
#  'ORLY',
#  'OXY',
#  'ODFL',
#  'OMC',
#  'ON',
#  'OKE',
#  'ORCL',
#  'OTIS',
#  'PCAR',
#  'PKG',
#  'PANW',
#  'PARA',
#  'PH',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PNR',
#  'PEP',
#  'PFE',
#  'PCG',
#  'PM',
#  'PSX',
#  'PNW',
#  'PXD',
#  'PNC',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PTC',
#  'PSA',
#  'PHM',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RVTY',
#  'RHI',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SEE',
#  'SRE',
#  'NOW',
#  'SHW',
#  'SPG',
#  'SWKS',
#  'SJM',
#  'SNA',
#  'SEDG',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'STLD',
#  'STE',
#  'SYK',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TRGP',
#  'TGT',
#  'TEL',
#  'TDY',
#  'TFX',
#  'TER',
#  'TSLA',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TRMB',
#  'TFC',
#  'TYL',
#  'TSN',
#  'USB',
#  'UDR',
#  'ULTA',
#  'UNP',
#  'UAL',
#  'UPS',
#  'URI',
#  'UNH',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VLTO',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VFC',
#  'VTRS',
#  'VICI',
#  'V',
#  'VMC',
#  'WAB',
#  'WBA',
#  'WMT',
#  'WBD',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WST',
#  'WDC',
#  'WRK',
#  'WY',
#  'WHR',
#  'WMB',
#  'WTW',
#  'GWW',
#  'WYNN',
#  'XEL',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZION',
#  'ZTS',
#  'COV',
#  'SWY',
#  'PETM',
#  'CFN',
#  'AVP',
#  'NBR',
#  'DNR',
#  'AGN',
#  'WIN',
#  'LO',
#  'QEP',
#  'TEG',
#  'ATI',
#  'KRFT',
#  'FDO',
#  'NE',
#  'DTV',
#  'PLL',
#  'HSP',
#  'JOY',
#  'HCBK',
#  'GNW',
#  'SIAL',
#  'CSC',
#  'CMCSK',
#  'ALTR',
#  'FOSL',
#  'ACE',
#  'BRCM',
#  'PCP',
#  'PCL',
#  'CNX',
#  'GMCR',
#  'ESV',
#  'POM',
#  'CAM',
#  'THC',
#  'GME',
#  'ADT',
#  'SNDK',
#  'TWC',
#  'ARG',
#  'CCE',
#  'BXLT',
#  'CVC',
#  'TE',
#  'GAS',
#  'CPGX',
#  'TYC',
#  'EMC',
#  'HOT',
#  'DO',
#  'AA',
#  'LM',
#  'OI',
#  'STJ',
#  'SE',
#  'PBI',
#  'ENDP',
#  'LLTC',
#  'HAR',
#  'FSLR',
#  'FTR',
#  'URBN',
#  'SWN',
#  'DNB',
#  'TGNA',
#  'MJN',
#  'R',
#  'TDC',
#  'YHOO',
#  'RAI',
#  'MNK',
#  'MUR',
#  'BBBY',
#  'RIG',
#  'AN',
#  'WFM',
#  'DD',
#  'DOW',
#  'SPLS',
#  'LVLT',
#  'BCR',
#  'SNI',
#  'CHK',
#  'PDCO',
#  'SIG',
#  'CSRA',
#  'WYN',
#  'NAVI',
#  'MON',
#  'AYI',
#  'RRC',
#  'TWX',
#  'DPS',
#  'GGP',
#  'XL',
#  'ANDV',
#  'EVHC',
#  'CA',
#  'EQT',
#  'SRCL',
#  'AET',
#  'COL',
#  'ESRX',
#  'SCG',
#  'PCG',
#  'NFX',
#  'GT',
#  'BHF',
#  'FLR',
#  'DWDP',
#  'MAT',
#  'BMS',
#  'LLL',
#  'RHT',
#  'FL',
#  'APC',
#  'TSS',
#  'JEF',
#  'NKTR',
#  'CELG',
#  'VIAB',
#  'STI',
#  'MAC',
#  'TRIP',
#  'AMG',
#  'WCG',
#  'XEC',
#  'ARNC',
#  'RTN',
#  'M',
#  'AGN',
#  'CPRI',
#  'HP',
#  'JWN',
#  'HOG',
#  'ADS',
#  'KSS',
#  'COTY',
#  'HRB',
#  'ETFC',
#  'NBL',
#  'AIV',
#  'TIF',
#  'CXO',
#  'FTI',
#  'VNT',
#  'XRX',
#  'SLG',
#  'FLS',
#  'VAR',
#  'FLIR',
#  'HFC',
#  'ALXN',
#  'MXIM',
#  'NOV',
#  'UNM',
#  'PRGO',
#  'KSU',
#  'WU',
#  'HBI',
#  'LEG',
#  'GPS',
#  'XLNX',
#  'INFO',
#  'PBCT',
#  'CERN',
#  'IPGP',
#  'UAA',
#  'UA',
#  'PENN',
#  'PVH',
#  'DRE',
#  'CTXS',
#  'NLSN',
#  'TWTR',
#  'MBC',
#  'FBHS',
#  'ABMD',
#  'VNO',
#  'SIVB',
#  'SBNY',
#  'LUMN',
#  'FRC',
#  'DISH',
#  'AAP',
#  'NWL',
#  'LNC',
#  'DXC',
#  'ATVI',
#  'OGN']

# %%
df = yf.download(stocks, start=start)['Close']
# Out:
# [*********************100%%**********************]  689 of 689 completed
# 83 Failed downloads:
# ['ENDP', 'ADS', 'NLSN', 'AGN', 'BRK.B', 'YHOO', 'VAR', 'PBCT', 'LM', 'XL', 'KSU', 'TSS', 'CXO', 'LLL', 'QEP', 'TIF', 'ESV', 'APC', 'DNR', 'XLNX', 'MON', 'INFO', 'FRC', 'DTV', 'ETFC', 'MXIM', 'FBHS', 'TWTR', 'SIVB', 'ARNC', 'RTN', 'FTR', 'DRE', 'WCG', 'WIN', 'BBBY', 'AVP', 'MNK', 'XEC', 'NBL', 'CELG', 'CTXS', 'ALXN', 'FLIR', 'HFC', 'DWDP', 'STI', 'RHT', 'VIAB', 'CERN']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['LLTC', 'SWY', 'SIAL', 'DPS', 'JOY', 'BF.B', 'SNDK', 'MJN', 'HCBK', 'TWC', 'CVC', 'WYN', 'KRFT', 'GGP', 'WFM', 'CMCSK', 'BCR', 'CFN', 'LO', 'GMCR', 'TE', 'TYC', 'STJ', 'CPGX', 'BRCM', 'RAI', 'BXLT', 'FDO', 'CAM', 'ARG', 'LVLT', 'HSP', 'SPLS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2015-01-01 -> 2023-11-23)')

# %%
df
# Out:
#                      A         AA        AAL         AAP        AAPL  \
# Date
# 2015-01-02   40.560001  38.159641  53.910000  158.559998   27.332500
# 2015-01-05   39.799999  35.948879  53.880001  156.470001   26.562500
# 2015-01-06   39.180000  36.213211  53.040001  156.360001   26.565001
# 2015-01-07   39.700001  37.150379  53.009998  159.720001   26.937500
# 2015-01-08   40.889999  38.207699  53.660000  161.119995   27.972500
# ...                ...        ...        ...         ...         ...
# 2023-11-16  114.190002  26.000000  12.190000   53.419998  189.710007
# 2023-11-17  113.150002  26.219999  12.290000   50.330002  189.690002
# 2023-11-20  113.980003  26.469999  12.400000   53.020000  191.449997
# 2023-11-21  123.919998  26.389999  12.130000   50.990002  190.639999
# 2023-11-22  123.989998  26.379999  12.310000   52.590000  191.309998
#
#                   ABBV       ABMD        ABNB         ABT  ACE  ...  \
# Date                                                            ...
# 2015-01-02   65.889999  37.310001         NaN   44.900002  NaN  ...
# 2015-01-05   64.650002  37.070000         NaN   44.910000  NaN  ...
# 2015-01-06   64.330002  36.130001         NaN   44.400002  NaN  ...
# 2015-01-07   66.930000  37.279999         NaN   44.759998  NaN  ...
# 2015-01-08   67.629997  38.959999         NaN   45.680000  NaN  ...
# ...                ...        ...         ...         ...  ...  ...
# 2023-11-16  138.279999        NaN  126.279999  100.260002  NaN  ...
# 2023-11-17  138.300003        NaN  127.150002   99.550003  NaN  ...
# 2023-11-20  138.309998        NaN  129.699997  101.199997  NaN  ...
# 2023-11-21  138.729996        NaN  126.820000  101.910004  NaN  ...
# 2023-11-22  138.470001        NaN  129.039993  102.699997  NaN  ...
#
#                    XOM       XRAY        XRX         XYL  YHOO         YUM  \
# Date
# 2015-01-02   92.830002  51.930000  36.231884   38.080002   NaN   52.012939
# 2015-01-05   90.290001  51.570000  35.441368   35.709999   NaN   50.956146
# 2015-01-06   89.809998  50.930000  34.967064   35.500000   NaN   50.330696
# 2015-01-07   90.720001  52.250000  35.415020   35.779999   NaN   51.998562
# 2015-01-08   92.230003  53.540001  36.389988   36.049999   NaN   52.904385
# ...                ...        ...        ...         ...   ...         ...
# 2023-11-16  102.459999  29.600000  13.580000  101.260002   NaN  127.830002
# 2023-11-17  104.959999  29.690001  13.770000  101.160004   NaN  127.660004
# 2023-11-20  104.500000  29.940001  13.620000  100.209999   NaN  128.119995
# 2023-11-21  104.459999  30.990000  13.560000  101.019997   NaN  128.240005
# 2023-11-22  104.010002  31.360001  13.630000  102.220001   NaN  128.940002
#
#                    ZBH        ZBRA       ZION         ZTS
# Date
# 2015-01-02  109.310677   77.430000  28.290001   43.310001
# 2015-01-05  113.388351   76.339996  27.230000   43.049999
# 2015-01-06  112.427185   75.790001  26.190001   42.630001
# 2015-01-07  115.223305   77.720001  26.440001   43.509998
# 2015-01-08  116.446602   79.379997  26.809999   44.180000
# ...                ...         ...        ...         ...
# 2023-11-16  111.550003  215.479996  35.709999  176.539993
# 2023-11-17  111.669998  218.020004  36.070000  174.800003
# 2023-11-20  112.500000  220.539993  35.779999  176.059998
# 2023-11-21  112.900002  222.410004  34.310001  178.729996
# 2023-11-22  113.830002  225.860001  34.410000  179.350006
#
# [2239 rows x 689 columns]

# %%
df.index = pd.to_datetime(df.index)

# %%
df
# Out:
#                      A         AA        AAL         AAP        AAPL  \
# Date
# 2015-01-02   40.560001  38.159641  53.910000  158.559998   27.332500
# 2015-01-05   39.799999  35.948879  53.880001  156.470001   26.562500
# 2015-01-06   39.180000  36.213211  53.040001  156.360001   26.565001
# 2015-01-07   39.700001  37.150379  53.009998  159.720001   26.937500
# 2015-01-08   40.889999  38.207699  53.660000  161.119995   27.972500
# ...                ...        ...        ...         ...         ...
# 2023-11-16  114.190002  26.000000  12.190000   53.419998  189.710007
# 2023-11-17  113.150002  26.219999  12.290000   50.330002  189.690002
# 2023-11-20  113.980003  26.469999  12.400000   53.020000  191.449997
# 2023-11-21  123.919998  26.389999  12.130000   50.990002  190.639999
# 2023-11-22  123.989998  26.379999  12.310000   52.590000  191.309998
#
#                   ABBV       ABMD        ABNB         ABT  ACE  ...  \
# Date                                                            ...
# 2015-01-02   65.889999  37.310001         NaN   44.900002  NaN  ...
# 2015-01-05   64.650002  37.070000         NaN   44.910000  NaN  ...
# 2015-01-06   64.330002  36.130001         NaN   44.400002  NaN  ...
# 2015-01-07   66.930000  37.279999         NaN   44.759998  NaN  ...
# 2015-01-08   67.629997  38.959999         NaN   45.680000  NaN  ...
# ...                ...        ...         ...         ...  ...  ...
# 2023-11-16  138.279999        NaN  126.279999  100.260002  NaN  ...
# 2023-11-17  138.300003        NaN  127.150002   99.550003  NaN  ...
# 2023-11-20  138.309998        NaN  129.699997  101.199997  NaN  ...
# 2023-11-21  138.729996        NaN  126.820000  101.910004  NaN  ...
# 2023-11-22  138.470001        NaN  129.039993  102.699997  NaN  ...
#
#                    XOM       XRAY        XRX         XYL  YHOO         YUM  \
# Date
# 2015-01-02   92.830002  51.930000  36.231884   38.080002   NaN   52.012939
# 2015-01-05   90.290001  51.570000  35.441368   35.709999   NaN   50.956146
# 2015-01-06   89.809998  50.930000  34.967064   35.500000   NaN   50.330696
# 2015-01-07   90.720001  52.250000  35.415020   35.779999   NaN   51.998562
# 2015-01-08   92.230003  53.540001  36.389988   36.049999   NaN   52.904385
# ...                ...        ...        ...         ...   ...         ...
# 2023-11-16  102.459999  29.600000  13.580000  101.260002   NaN  127.830002
# 2023-11-17  104.959999  29.690001  13.770000  101.160004   NaN  127.660004
# 2023-11-20  104.500000  29.940001  13.620000  100.209999   NaN  128.119995
# 2023-11-21  104.459999  30.990000  13.560000  101.019997   NaN  128.240005
# 2023-11-22  104.010002  31.360001  13.630000  102.220001   NaN  128.940002
#
#                    ZBH        ZBRA       ZION         ZTS
# Date
# 2015-01-02  109.310677   77.430000  28.290001   43.310001
# 2015-01-05  113.388351   76.339996  27.230000   43.049999
# 2015-01-06  112.427185   75.790001  26.190001   42.630001
# 2015-01-07  115.223305   77.720001  26.440001   43.509998
# 2015-01-08  116.446602   79.379997  26.809999   44.180000
# ...                ...         ...        ...         ...
# 2023-11-16  111.550003  215.479996  35.709999  176.539993
# 2023-11-17  111.669998  218.020004  36.070000  174.800003
# 2023-11-20  112.500000  220.539993  35.779999  176.059998
# 2023-11-21  112.900002  222.410004  34.310001  178.729996
# 2023-11-22  113.830002  225.860001  34.410000  179.350006
#
# [2239 rows x 689 columns]

# %%
overall
# Out:
#     Symbol                         Security             GICS Sector  \
# 1      AOS                      A. O. Smith             Industrials
# 11    ABNB                           Airbnb  Consumer Discretionary
# 14     ALK                 Alaska Air Group             Industrials
# 15     ALB            Albemarle Corporation               Materials
# 16     ARE  Alexandria Real Estate Equities             Real Estate
# ..     ...                              ...                     ...
# 478    WAB                           Wabtec             Industrials
# 481    WBD           Warner Bros. Discovery  Communication Services
# 487    WST     West Pharmaceutical Services             Health Care
# 493    WTW             Willis Towers Watson              Financials
# 499   ZBRA               Zebra Technologies  Information Technology
#
#                                      GICS Sub-Industry  \
# 1                                    Building Products
# 11                      Hotels, Resorts & Cruise Lines
# 14                                  Passenger Airlines
# 15                                 Specialty Chemicals
# 16                                        Office REITs
# ..                                                 ...
# 478  Construction Machinery & Heavy Transportation ...
# 481                                       Broadcasting
# 487                               Health Care Supplies
# 493                                  Insurance Brokers
# 499                 Electronic Equipment & Instruments
#
#          Headquarters Location  Date added      CIK                   Founded
# 1         Milwaukee, Wisconsin  2017-07-26    91142                      1916
# 11   San Francisco, California  2023-09-18  1559720                      2008
# 14          SeaTac, Washington  2016-05-13   766421                      1985
# 15   Charlotte, North Carolina  2016-07-01   915913                      1994
# 16        Pasadena, California  2017-03-20  1035443                      1994
# ..                         ...         ...      ...                       ...
# 478   Pittsburgh, Pennsylvania  2019-02-27   943452               1999 (1869)
# 481    New York City, New York  2022-04-11  1437107  2022 (Warner Bros. 1923)
# 487        Exton, Pennsylvania  2020-05-22   105770                      1923
# 493     London, United Kingdom  2016-01-05  1140536                      2016
# 499     Lincolnshire, Illinois  2019-12-23   877212                      1969
#
# [159 rows x 8 columns]

# %%
def pricefilter_rmv(ticker):
    df[ticker] = df[ticker][df[ticker].index <= removed[removed.Ticker == ticker ].index[0]]

# %%
def pricefilter_add(ticker):
    df[ticker] = df[ticker][df[ticker].index >= overall[overall.Symbol == ticker]['Date added'].values[0]]

# %%
for ticker_rem in removed.Ticker:
    pricefilter_rmv(ticker_rem)
for ticker_add in overall.Symbol:
    pricefilter_add(ticker_add)

# %%
df
# Out:
#                      A         AA    AAL         AAP        AAPL        ABBV  \
# Date
# 2015-01-02   40.560001  38.159641    NaN  158.559998   27.332500   65.889999
# 2015-01-05   39.799999  35.948879    NaN  156.470001   26.562500   64.650002
# 2015-01-06   39.180000  36.213211    NaN  156.360001   26.565001   64.330002
# 2015-01-07   39.700001  37.150379    NaN  159.720001   26.937500   66.930000
# 2015-01-08   40.889999  38.207699    NaN  161.119995   27.972500   67.629997
# ...                ...        ...    ...         ...         ...         ...
# 2023-11-16  114.190002        NaN  12.19         NaN  189.710007  138.279999
# 2023-11-17  113.150002        NaN  12.29         NaN  189.690002  138.300003
# 2023-11-20  113.980003        NaN  12.40         NaN  191.449997  138.309998
# 2023-11-21  123.919998        NaN  12.13         NaN  190.639999  138.729996
# 2023-11-22  123.989998        NaN  12.31         NaN  191.309998  138.470001
#
#                  ABMD        ABNB         ABT  ACE  ...         XOM  \
# Date                                                ...
# 2015-01-02  37.310001         NaN   44.900002  NaN  ...   92.830002
# 2015-01-05  37.070000         NaN   44.910000  NaN  ...   90.290001
# 2015-01-06  36.130001         NaN   44.400002  NaN  ...   89.809998
# 2015-01-07  37.279999         NaN   44.759998  NaN  ...   90.720001
# 2015-01-08  38.959999         NaN   45.680000  NaN  ...   92.230003
# ...               ...         ...         ...  ...  ...         ...
# 2023-11-16        NaN  126.279999  100.260002  NaN  ...  102.459999
# 2023-11-17        NaN  127.150002   99.550003  NaN  ...  104.959999
# 2023-11-20        NaN  129.699997  101.199997  NaN  ...  104.500000
# 2023-11-21        NaN  126.820000  101.910004  NaN  ...  104.459999
# 2023-11-22        NaN  129.039993  102.699997  NaN  ...  104.010002
#
#                  XRAY        XRX         XYL  YHOO         YUM         ZBH  \
# Date
# 2015-01-02  51.930000  36.231884   38.080002   NaN   52.012939  109.310677
# 2015-01-05  51.570000  35.441368   35.709999   NaN   50.956146  113.388351
# 2015-01-06  50.930000  34.967064   35.500000   NaN   50.330696  112.427185
# 2015-01-07  52.250000  35.415020   35.779999   NaN   51.998562  115.223305
# 2015-01-08  53.540001  36.389988   36.049999   NaN   52.904385  116.446602
# ...               ...        ...         ...   ...         ...         ...
# 2023-11-16  29.600000        NaN  101.260002   NaN  127.830002  111.550003
# 2023-11-17  29.690001        NaN  101.160004   NaN  127.660004  111.669998
# 2023-11-20  29.940001        NaN  100.209999   NaN  128.119995  112.500000
# 2023-11-21  30.990000        NaN  101.019997   NaN  128.240005  112.900002
# 2023-11-22  31.360001        NaN  102.220001   NaN  128.940002  113.830002
#
#                   ZBRA       ZION         ZTS
# Date
# 2015-01-02         NaN  28.290001   43.310001
# 2015-01-05         NaN  27.230000   43.049999
# 2015-01-06         NaN  26.190001   42.630001
# 2015-01-07         NaN  26.440001   43.509998
# 2015-01-08         NaN  26.809999   44.180000
# ...                ...        ...         ...
# 2023-11-16  215.479996  35.709999  176.539993
# 2023-11-17  218.020004  36.070000  174.800003
# 2023-11-20  220.539993  35.779999  176.059998
# 2023-11-21  222.410004  34.310001  178.729996
# 2023-11-22  225.860001  34.410000  179.350006
#
# [2239 rows x 689 columns]

# %%
removed
# Out:
#            Ticker                      Security
# Date
# 2015-01-27    COV                      Covidien
# 2015-01-27    SWY                       Safeway
# 2015-03-12   PETM                      PetSmart
# 2015-03-18    CFN                    Carefusion
# 2015-03-23    AVP                 Avon Products
# ...           ...                           ...
# 2023-09-18    NWL                 Newell Brands
# 2023-09-18    LNC  Lincoln National Corporation
# 2023-10-03    DXC                DXC Technology
# 2023-10-18   ATVI           Activision Blizzard
# 2023-10-18    OGN                 Organon & Co.
#
# [192 rows x 2 columns]

# %%
ret_df = df.pct_change()

# %%
ret_df
# Out:
#                    A        AA       AAL       AAP      AAPL      ABBV  \
# Date
# 2015-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-01-05 -0.018738 -0.057935       NaN -0.013181 -0.028172 -0.018819
# 2015-01-06 -0.015578  0.007353       NaN -0.000703  0.000094 -0.004950
# 2015-01-07  0.013272  0.025879       NaN  0.021489  0.014022  0.040417
# 2015-01-08  0.029975  0.028461       NaN  0.008765  0.038422  0.010459
# ...              ...       ...       ...       ...       ...       ...
# 2023-11-16  0.005194  0.000000 -0.018519  0.000000  0.009042  0.004942
# 2023-11-17 -0.009108  0.000000  0.008203  0.000000 -0.000105  0.000145
# 2023-11-20  0.007335  0.000000  0.008950  0.000000  0.009278  0.000072
# 2023-11-21  0.087208  0.000000 -0.021774  0.000000 -0.004231  0.003037
# 2023-11-22  0.000565  0.000000  0.014839  0.000000  0.003514 -0.001874
#
#                 ABMD      ABNB       ABT  ACE  ...       XOM      XRAY  \
# Date                                           ...
# 2015-01-02       NaN       NaN       NaN  NaN  ...       NaN       NaN
# 2015-01-05 -0.006433       NaN  0.000223  NaN  ... -0.027362 -0.006932
# 2015-01-06 -0.025357       NaN -0.011356  NaN  ... -0.005316 -0.012410
# 2015-01-07  0.031829       NaN  0.008108  NaN  ...  0.010133  0.025918
# 2015-01-08  0.045064       NaN  0.020554  NaN  ...  0.016645  0.024689
# ...              ...       ...       ...  ...  ...       ...       ...
# 2023-11-16  0.000000 -0.016128  0.023061  NaN  ... -0.011576  0.009550
# 2023-11-17  0.000000  0.006889 -0.007082  NaN  ...  0.024400  0.003041
# 2023-11-20  0.000000  0.020055  0.016575  NaN  ... -0.004383  0.008420
# 2023-11-21  0.000000 -0.022205  0.007016  NaN  ... -0.000383  0.035070
# 2023-11-22  0.000000  0.017505  0.007752  NaN  ... -0.004308  0.011939
#
#                  XRX       XYL  YHOO       YUM       ZBH      ZBRA      ZION  \
# Date
# 2015-01-02       NaN       NaN   NaN       NaN       NaN       NaN       NaN
# 2015-01-05 -0.021818 -0.062237   NaN -0.020318  0.037304       NaN -0.037469
# 2015-01-06 -0.013383 -0.005881   NaN -0.012274 -0.008477       NaN -0.038193
# 2015-01-07  0.012811  0.007887   NaN  0.033138  0.024870       NaN  0.009546
# 2015-01-08  0.027530  0.007546   NaN  0.017420  0.010617       NaN  0.013994
# ...              ...       ...   ...       ...       ...       ...       ...
# 2023-11-16  0.000000  0.010176   NaN  0.009556  0.009502 -0.006822 -0.010255
# 2023-11-17  0.000000 -0.000988   NaN -0.001330  0.001076  0.011788  0.010081
# 2023-11-20  0.000000 -0.009391   NaN  0.003603  0.007433  0.011559 -0.008040
# 2023-11-21  0.000000  0.008083   NaN  0.000937  0.003556  0.008479 -0.041084
# 2023-11-22  0.000000  0.011879   NaN  0.005458  0.008237  0.015512  0.002915
#
#                  ZTS
# Date
# 2015-01-02       NaN
# 2015-01-05 -0.006003
# 2015-01-06 -0.009756
# 2015-01-07  0.020643
# 2015-01-08  0.015399
# ...              ...
# 2023-11-16  0.010995
# 2023-11-17 -0.009856
# 2023-11-20  0.007208
# 2023-11-21  0.015165
# 2023-11-22  0.003469
#
# [2239 rows x 689 columns]

# %%
mtl_ret = (ret_df + 1).resample('M').prod()

# %%
mtl_ret
# Out:
#                    A        AA       AAL       AAP      AAPL      ABBV  \
# Date
# 2015-01-31  0.931213  0.985516  1.000000  1.002775  1.071618  0.915920
# 2015-02-28  1.117554  0.945048  1.000000  0.974402  1.096449  1.002486
# 2015-03-31  0.984364  0.873563  0.970221  0.966178  0.968628  0.967603
# 2015-04-30  0.995668  1.038700  0.914930  0.955308  1.005786  1.104544
# 2015-05-31  0.995649  0.931446  0.877407  1.071469  1.040991  1.029848
# ...              ...       ...       ...       ...       ...       ...
# 2023-07-31  1.012640  1.000000  0.933668  1.058179  1.012785  1.110220
# 2023-08-31  0.994251  1.000000  0.879403  0.861406  0.956325  0.982484
# 2023-09-30  0.923598  1.000000  0.869654  1.000000  0.911322  1.014290
# 2023-10-31  0.924432  1.000000  0.870414  1.000000  0.997430  0.947135
# 2023-11-30  1.199478  1.000000  1.104036  1.000000  1.120279  0.980805
#
#                 ABMD      ABNB       ABT  ACE  ...       XOM      XRAY  \
# Date                                           ...
# 2015-01-31  1.386760  1.000000  0.996882  1.0  ...  0.941721  0.963412
# 2015-02-28  1.174913  1.000000  1.058311  1.0  ...  1.012812  1.059564
# 2015-03-31  1.177496  1.000000  0.978045  1.0  ...  0.960018  0.960008
# 2015-04-30  0.883208  1.000000  1.001943  1.0  ...  1.027882  1.002162
# 2015-05-31  0.944638  1.000000  1.046963  1.0  ...  0.975163  1.020392
# ...              ...       ...       ...  ...  ...       ...       ...
# 2023-07-31  1.000000  1.000000  1.021189  1.0  ...  0.999907  1.037481
# 2023-08-31  1.000000  1.000000  0.924279  1.0  ...  1.036833  0.893304
# 2023-09-30  1.000000  0.962539  0.941205  1.0  ...  1.057469  0.921003
# 2023-10-31  1.000000  0.862109  0.976252  1.0  ...  0.900238  0.890222
# 2023-11-30  1.000000  1.090878  1.086198  1.0  ...  0.982617  1.031240
#
#                  XRX       XYL  YHOO       YUM       ZBH      ZBRA      ZION  \
# Date
# 2015-01-31  0.957818  0.895483   1.0  0.999032  0.995648  1.000000  0.846942
# 2015-02-28  1.036447  1.046921   1.0  1.122164  1.073952  1.000000  1.116027
# 2015-03-31  0.941392  0.980952   1.0  0.970534  0.976161  1.000000  1.009723
# 2015-04-30  0.894942  1.057110   1.0  1.091972  0.934649  1.000000  1.049630
# 2015-05-31  0.993044  0.987844   1.0  1.048278  1.038693  1.000000  1.019054
# ...              ...       ...   ...       ...       ...       ...       ...
# 2023-07-31  1.000000  1.001154   1.0  0.993648  0.948832  1.041003  1.424051
# 2023-08-31  1.000000  0.918315   1.0  0.939784  0.862251  0.893006  0.928105
# 2023-09-30  1.000000  0.879177   1.0  0.965682  0.942075  0.860078  0.982817
# 2023-10-31  1.000000  1.027573   1.0  0.967344  0.930405  0.885427  0.884208
# 2023-11-30  1.000000  1.092795   1.0  1.066854  1.090221  1.078451  1.115397
#
#                  ZTS
# Date
# 2015-01-31  0.986608
# 2015-02-28  1.078633
# 2015-03-31  1.004339
# 2015-04-30  0.959602
# 2015-05-31  1.120441
# ...              ...
# 2023-07-31  1.092213
# 2023-08-31  1.012866
# 2023-09-30  0.913233
# 2023-10-31  0.902403
# 2023-11-30  1.142357
#
# [107 rows x 689 columns]

# %%
mtl_12 = mtl_ret.rolling(12).apply(np.prod).dropna()

# %%
mtl_12
# Out:
#                    A        AA       AAL       AAP      AAPL      ABBV  \
# Date
# 2015-12-31  1.030819  0.621536  0.778493  0.949231  0.962773  0.899074
# 2016-01-31  0.996823  0.465815  0.716728  0.956289  0.830830  0.909694
# 2016-02-29  0.884861  0.603786  0.753676  0.958110  0.752686  0.902645
# 2016-03-31  0.959085  0.741486  0.776999  1.071147  0.875914  0.975743
# 2016-04-30  0.989123  0.832340  0.718368  1.091608  0.749021  0.943396
# ...              ...       ...       ...       ...       ...       ...
# 2023-07-31  0.908054  1.000000  1.221736  0.384206  1.208849  1.042297
# 2023-08-31  0.944016  1.000000  1.133949  0.379981  1.194950  1.092964
# 2023-09-30  0.919951  1.000000  1.063954  0.409876  1.238857  1.110647
# 2023-10-31  0.747163  1.000000  0.786319  0.337405  1.113669  0.964344
# 2023-11-30  0.800039  1.000000  0.853084  0.424399  1.292373  0.859102
#
#                 ABMD      ABNB       ABT  ACE  ...       XOM      XRAY  \
# Date                                           ...
# 2015-12-31  2.419726  1.000000  1.000223  1.0  ...  0.839707  1.171770
# 2016-01-31  1.649208  1.000000  0.845621  1.0  ...  0.890528  1.177094
# 2016-02-29  1.316170  1.000000  0.817817  1.0  ...  0.905241  1.149972
# 2016-03-31  1.324532  1.000000  0.902871  1.0  ...  0.983412  1.211043
# 2016-04-30  1.536539  1.000000  0.838001  1.0  ...  1.011789  1.168627
# ...              ...       ...       ...  ...  ...       ...       ...
# 2023-07-31  1.300365  1.000000  1.022878  1.0  ...  1.106365  1.148230
# 2023-08-31  1.469531  1.000000  1.002435  1.0  ...  1.163197  1.131828
# 2023-09-30  1.551005  0.962539  1.000930  1.0  ...  1.346696  1.204938
# 2023-10-31  1.511504  0.829814  0.955630  1.0  ...  0.955239  0.986697
# 2023-11-30  1.008550  0.905226  0.954638  1.0  ...  0.934166  1.036352
#
#                  XRX       XYL  YHOO       YUM       ZBH      ZBRA      ZION  \
# Date
# 2015-12-31  0.773091  0.958508   1.0  1.009675  0.911182  1.000000  0.965005
# 2016-01-31  0.740319  1.054252   1.0  1.001245  0.885459  1.000000  0.946578
# 2016-02-29  0.704029  1.047899   1.0  0.893478  0.804137  1.000000  0.797307
# 2016-03-31  0.868482  1.167904   1.0  1.039761  0.907335  1.000000  0.896667
# 2016-04-30  0.834783  1.128579   1.0  0.925547  1.053988  1.000000  0.971066
# ...              ...       ...   ...       ...       ...       ...       ...
# 2023-07-31  1.000000  1.225144   1.0  1.123470  1.251472  0.860969  0.701192
# 2023-08-31  1.000000  1.136553   1.0  1.163071  1.120391  0.911716  0.645103
# 2023-09-30  1.000000  1.042010   1.0  1.174911  1.073362  0.902752  0.686001
# 2023-10-31  1.000000  0.913209   1.0  1.022072  0.921129  0.739460  0.593955
# 2023-11-30  1.000000  0.909835   1.0  1.002176  0.947794  0.835652  0.664029
#
#                  ZTS
# Date
# 2015-12-31  1.106442
# 2016-01-31  1.007489
# 2016-02-29  0.890866
# 2016-03-31  0.957658
# 2016-04-30  1.058757
# ...              ...
# 2023-07-31  1.030348
# 2023-08-31  1.217083
# 2023-09-30  1.173242
# 2023-10-31  1.041252
# 2023-11-30  1.163553
#
# [96 rows x 689 columns]

# %%
def top_performer(date):
    all_ = mtl_12.loc[date]
    top = all_.nlargest(5)
    relevent_ret = mtl_ret[top.name:][1:2][top.index]
    return relevent_ret.mean(axis = 1).values[0]

# %%
top_performer('2015-12-31')
# Out:
# 0.8763854757262127

# %%
returns = []
for date in mtl_12.index[:-1]:
    returns.append(top_performer(date))

# %%
returns
# Out:
# [0.8763854757262127,
#  0.9832905711832769,
#  1.0703352863339657,
#  0.9735766117556703,
#  1.0583740920185012,
#  1.0237384726258656,
#  1.0985056536366908,
#  0.9999976319345734,
#  1.037976230260604,
#  0.9730309727186075,
#  1.0161213309242345,
#  1.0184843713055538,
#  1.0713537244343485,
#  0.9398540679892365,
#  1.0630706657019364,
#  0.9665088182423147,
#  1.1331689017289057,
#  0.9704484032994356,
#  0.9897126285016151,
#  1.0325751782205832,
#  1.06882528038826,
#  1.1076136160195442,
#  1.006157505731307,
#  1.0010827264640474,
#  1.1243892220554113,
#  0.9939755586841754,
#  1.0575878778101822,
#  0.9526778577289864,
#  1.1153470916239228,
#  0.9444806388545601,
#  0.9671131422557331,
#  1.1022210982664198,
#  1.006816342270703,
#  0.6691776651115933,
#  0.9648532955045368,
#  0.8117655589147222,
#  1.1407542513597844,
#  1.0287597312992312,
#  1.0600839751078133,
#  1.0092887686371317,
#  0.9340846971840584,
#  1.058756835391009,
#  1.0520786540081128,
#  1.0315930646191993,
#  0.9493135208856638,
#  1.0026785800527311,
#  1.0428544755855533,
#  1.0412339167244007,
#  0.9748244235044865,
#  0.9217480439536925,
#  0.8638422381602338,
#  1.0971368552154004,
#  1.0930801618642734,
#  1.0058667442992761,
#  1.1551032820769571,
#  1.1200699353814445,
#  1.0275171783545112,
#  0.899630005486347,
#  1.1898583262533253,
#  1.0547001977769466,
#  1.0626047505669045,
#  1.098005389957657,
#  0.9325122437968896,
#  1.0578650096735362,
#  1.012316811693891,
#  0.9623002310537586,
#  0.9725590545362447,
#  1.001716912829175,
#  1.0057552862316856,
#  1.1364273906675098,
#  0.978715447601941,
#  1.0540094366136998,
#  1.0159871088954424,
#  1.1148411476039684,
#  1.0439823103468904,
#  0.975397870113379,
#  1.1951091313358795,
#  0.7588342407761468,
#  1.104257948917617,
#  1.0741974979512814,
#  0.8807679086362221,
#  1.1647795234650211,
#  0.9694660969544122,
#  0.936125172823853,
#  1.0618426012249642,
#  0.9387966461162293,
#  1.0601573690582715,
#  0.9962638136340104,
#  0.9890859315945721,
#  1.064509835669134,
#  1.0386920695464137,
#  0.9466671186667159,
#  0.9103074281714975,
#  0.9674045477195581,
#  1.155869975286836]

# %%
pd.Series(returns).prod()
# Out:
# 3.339585318876708

# %%
pd.Series(returns, index=mtl_12.index[:-1]).cumprod().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
S_P500 = yf.download('^GSPC', start=start).Close
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
S_P500
# Out:
# Date
# 2015-01-02    2058.199951
# 2015-01-05    2020.579956
# 2015-01-06    2002.609985
# 2015-01-07    2025.900024
# 2015-01-08    2062.139893
#                  ...
# 2023-11-16    4508.240234
# 2023-11-17    4514.020020
# 2023-11-20    4547.379883
# 2023-11-21    4538.189941
# 2023-11-22    4556.620117
# Name: Close, Length: 2239, dtype: float64

# %%
S_P500.iloc[-1]/S_P500.iloc[0]
# Out:
# 2.213886029194152
